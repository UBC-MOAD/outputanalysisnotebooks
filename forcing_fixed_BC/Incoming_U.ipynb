# %% [markdown]
# #  Defining incoming U

# %% [markdown]
# ### Low body focing experiment
# Run01 is simular to the base case (CNTDIFF run38) but with half the body forcing after the initial 3 day push.
# I will compare this run to the base case.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from netCDF4 import Dataset
import numpy as np
import seaborn as sns
import xarray as xr

# %%
# grid files
grid_file = '/ocean/kramosmu/MITgcm/TracerExperiments/CNTDIFF/run38/gridGlob.nc'
grid = xr.open_dataset(grid_file)

# State and ptracer files for run with lower bf
#state_file01 = '/ocean/kramosmu/MITgcm/TracerExperiments/LESS_BF/run01/stateGlob.nc'
#ptracers_file01 = '/ocean/kramosmu/MITgcm/TracerExperiments/LESS_BF/run01/ptracersGlob.nc'

#state_01 = xr.open_dataset(state_file01)
#ptracers_01 = xr.open_dataset(ptracers_file01)

# State and ptracer files for run with lowest bf
#state_file03 = '/ocean/kramosmu/MITgcm/TracerExperiments/LESS_BF/run03/stateGlob.nc'
#ptracers_file03 = '/ocean/kramosmu/MITgcm/TracerExperiments/LESS_BF/run03/ptracersGlob.nc'

#state_03 = xr.open_dataset(state_file03)
#ptracers_03 = xr.open_dataset(ptracers_file03)

# State and ptracer files for spindown run
state_file_spndn = '/ocean/kramosmu/MITgcm/TracerExperiments/FORCING_SPNDN/run01/stateGlob.nc'
ptracers_file_spndn = '/ocean/kramosmu/MITgcm/TracerExperiments/FORCING_SPNDN/run01/ptracersGlob.nc'

state_spndn = xr.open_dataset(state_file_spndn)
ptracers_spndn = xr.open_dataset(ptracers_file_spndn)

# files for original run with body forcing
state_file_bf = '/ocean/kramosmu/MITgcm/TracerExperiments/CNTDIFF/run38/stateGlob.nc' 
ptracers_file_bf = '/ocean/kramosmu/MITgcm/TracerExperiments/CNTDIFF/run38/ptracersGlob.nc'

state_bf = xr.open_dataset(state_file_bf)
ptracers_bf = xr.open_dataset(ptracers_file_bf)

# files for run with fixed u,v boundaries
state_file_fix = '/ocean/kramosmu/MITgcm/TracerExperiments/EW_OBCS/run06/stateGlob.nc' 
ptracers_file_fix = '/ocean/kramosmu/MITgcm/TracerExperiments/EW_OBCS/run06/ptracersGlob.nc'

state_fix = xr.open_dataset(state_file_fix)
ptracers_fix = xr.open_dataset(ptracers_file_fix)

# %% [markdown]
#  ###  U and V, base case vs low bf case

# %%
# low bf case - west/east shelf on day 3
u_Wbdy_d3 = state_01.U.isel(Xp1=50, T=6)
v_Wbdy_d3 = state_01.V.isel(X=50, T=6)

u_Ebdy_d3 = state_01.U.isel(Xp1=310, T=6)
v_Ebdy_d3 = state_01.V.isel(X=310, T=6)

# low bf case - west/east shelf on day 6
u_Wbdy_d6 = state_01.U.isel(Xp1=50, T=12)
v_Wbdy_d6 = state_01.V.isel(X=50, T=12)

u_Ebdy_d6 = state_01.U.isel(Xp1=310, T=12)
v_Ebdy_d6 = state_01.V.isel(X=310, T=12)

# low bf case - shelf on day 9
u_Wbdy_d9 = state_01.U.isel(Xp1=50, T=18)
v_Wbdy_d9 = state_01.V.isel(X=50, T=18)

u_Ebdy_d9 = state_01.U.isel(Xp1=310, T=18)
v_Ebdy_d9 = state_01.V.isel(X=310, T=18)


# low bf case - mid alongshore distance, day 3
u_mid_d3 = state_01.U.isel(Xp1=180, T=6)
v_mid_d3 = state_01.V.isel(X=180, T=6)

# low bf case - mid alongshore distance, day 6
u_mid_d6 = state_01.U.isel(Xp1=180, T=12)
v_mid_d6 = state_01.V.isel(X=180, T=12)

# low bf case - mid alongshore distance, day 9
u_mid_d9 = state_01.U.isel(Xp1=180, T=18)
v_mid_d9 = state_01.V.isel(X=180, T=18)

# body forcing case on day 3
ubf_Wbdy_d3 = state_bf.U.isel(Xp1=50, T=6)
vbf_Wbdy_d3 = state_bf.V.isel(X=50, T=6)

ubf_Ebdy_d3 = state_bf.U.isel(Xp1=310, T=6)
vbf_Ebdy_d3 = state_bf.V.isel(X=310, T=6)

# body forcing case on day 6
ubf_Wbdy_d6 = state_bf.U.isel(Xp1=50, T=12)
vbf_Wbdy_d6 = state_bf.V.isel(X=50, T=12)

ubf_Ebdy_d6 = state_bf.U.isel(Xp1=310, T=12)
vbf_Ebdy_d6 = state_bf.V.isel(X=310, T=12)

# body forcing case on day 9
ubf_Wbdy_d9 = state_bf.U.isel(Xp1=50, T=18)
vbf_Wbdy_d9 = state_bf.V.isel(X=50, T=18)

ubf_Ebdy_d9 = state_bf.U.isel(Xp1=310, T=18)
vbf_Ebdy_d9 = state_bf.V.isel(X=310, T=18)

# body forcing case - mid alongshore distance, day 3
ubf_mid_d3 = state_bf.U.isel(Xp1=180, T=6)
vbf_mid_d3 = state_bf.V.isel(X=180, T=6)

# body forcing case - mid alongshore distance, day 6
ubf_mid_d6 = state_bf.U.isel(Xp1=180, T=12)
vbf_mid_d6 = state_bf.V.isel(X=180, T=12)

# body forcing case - mid alongshore distance, day 9
ubf_mid_d9 = state_bf.U.isel(Xp1=180, T=18)
vbf_mid_d9 = state_bf.V.isel(X=180, T=18)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e5b17c5d857f> in <module>()
#       1 # low bf case - west/east shelf on day 3
# ----> 2 u_Wbdy_d3 = state_01.U.isel(Xp1=50, T=6)
#       3 v_Wbdy_d3 = state_01.V.isel(X=50, T=6)
#       4
#       5 u_Ebdy_d3 = state_01.U.isel(Xp1=310, T=6)
#
# NameError: name 'state_01' is not defined

# %%
print('Day 3 vs day 3')
sns.set_context('talk')
fig,ax = plt.subplots(3,3,figsize=(18,10), sharey = True)

cf1 = ax[0,0].contourf(grid.Y/1000,grid.RC,u_Wbdy_d3,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf1,ax = ax[0,0])
ax[0,0].set_title('West shelf- low bf case, u at day 3')
ax[0,0].set_xlabel('CS distance (m)')

cf2 = ax[1,0].contourf(grid.Y/1000,grid.RC,u_mid_d3,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf2,ax = ax[1,0])
ax[1,0].set_title('mid - low bf case, u at day 3')
ax[1,0].set_xlabel('CS distance (m)')

cf3 = ax[2,0].contourf(grid.Y/1000,grid.RC,u_Ebdy_d3,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf3,ax = ax[2,0])
ax[2,0].set_title('East shelf -fixed boundary case, u at day 3')
ax[2,0].set_xlabel('CS distance (m)')

cf4 = ax[0,1].contourf(grid.Y/1000,grid.RC,ubf_Wbdy_d3,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf4,ax = ax[0,1])
ax[0,1].set_title('West shelf -body forcing case, u at day 3')
ax[0,1].set_xlabel('CS distance (m)')

cf5 = ax[1,1].contourf(grid.Y/1000,grid.RC,ubf_mid_d3,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf5,ax = ax[1,1])
ax[1,1].set_title('mid -body forcing case, u at day 3')
ax[1,1].set_xlabel('CS distance (m)')

cf6 = ax[2,1].contourf(grid.Y/1000,grid.RC,ubf_Ebdy_d3,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf6,ax = ax[2,1])
ax[2,1].set_title('East shelf -body forcing case, u at day 3')
ax[2,1].set_xlabel('CS distance (m)')

cf7 = ax[0,2].contourf(grid.Y/1000,grid.RC,ubf_Wbdy_d3.data-u_Wbdy_d3.data,20, cmap = 'RdYlBu_r', vmax = 0.2, vmin = -0.2)
plt.colorbar(cf7,ax = ax[0,2])
ax[0,2].set_title('West shelf anomaly')
ax[0,2].set_xlabel('CS distance (m)')

cf8 = ax[1,2].contourf(grid.Y/1000,grid.RC,ubf_mid_d3.data-u_mid_d3.data,20, cmap = 'RdYlBu_r', vmax = 0.2, vmin = -0.2)
plt.colorbar(cf8,ax = ax[1,2])
ax[1,2].set_title('mid anomaly')
ax[1,2].set_xlabel('CS distance (m)')

cf9 = ax[2,2].contourf(grid.Y/1000,grid.RC,ubf_Ebdy_d3.data-u_Ebdy_d3.data,20, cmap = 'RdYlBu_r', vmax = 0.2, vmin = -0.2)
plt.colorbar(cf9,ax = ax[2,2])
ax[2,2].set_title('East shelf anomaly')
ax[2,2].set_xlabel('CS distance (m)')


plt.tight_layout()
# Out:
# Day 3 vs day 3

# %%
print('Day 6 body forcing vs day 6 low bf')
sns.set_context('talk')
fig,ax = plt.subplots(3,3,figsize=(18,10), sharey = True)

cf1 = ax[0,0].contourf(grid.Y/1000,grid.RC,u_Wbdy_d6,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf1,ax = ax[0,0])
ax[0,0].set_title('W bdy - low bf case, u at day 6')
ax[0,0].set_xlabel('CS distance (m)')

cf2 = ax[1,0].contourf(grid.Y/1000,grid.RC,u_mid_d6,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf2,ax = ax[1,0])
ax[1,0].set_title('mid - low bf case, u at day 6')
ax[1,0].set_xlabel('CS distance (m)')

cf3 = ax[2,0].contourf(grid.Y/1000,grid.RC,u_Ebdy_d6,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf3,ax = ax[2,0])
ax[2,0].set_title('E bdy -fixed boundary case, u at day 6')
ax[2,0].set_xlabel('CS distance (m)')

cf4 = ax[0,1].contourf(grid.Y/1000,grid.RC,ubf_Wbdy_d6,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf4,ax = ax[0,1])
ax[0,1].set_title('W bdy -body forcing case, u at day 6')
ax[0,1].set_xlabel('CS distance (m)')

cf5 = ax[1,1].contourf(grid.Y/1000,grid.RC,ubf_mid_d6,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf5,ax = ax[1,1])
ax[1,1].set_title('mid -body forcing case, u at day 6')
ax[1,1].set_xlabel('CS distance (m)')

cf6 = ax[2,1].contourf(grid.Y/1000,grid.RC,ubf_Ebdy_d6,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf6,ax = ax[2,1])
ax[2,1].set_title('E bdy -body forcing case, u at day 6')
ax[2,1].set_xlabel('CS distance (m)')


cf7 = ax[0,2].contourf(grid.Y/1000,grid.RC,u_Wbdy_d6.data-ubf_Wbdy_d6.data,20, cmap = 'RdYlBu_r', vmax = 0.2, vmin = -0.2)
plt.colorbar(cf7,ax = ax[0,2])
ax[0,2].set_title('W bdy anomaly')
ax[0,2].set_xlabel('CS distance (m)')

cf8 = ax[1,2].contourf(grid.Y/1000,grid.RC,u_mid_d6.data-ubf_mid_d6.data,20, cmap = 'RdYlBu_r', vmax = 0.2, vmin = -0.2)
plt.colorbar(cf8,ax = ax[1,2])
ax[1,2].set_title('mid anomaly')
ax[1,2].set_xlabel('CS distance (m)')

cf9 = ax[2,2].contourf(grid.Y/1000,grid.RC,u_Ebdy_d6.data-ubf_Ebdy_d6.data,20, cmap = 'RdYlBu_r', vmax = 0.2, vmin = -0.2)
plt.colorbar(cf9,ax = ax[2,2])
ax[2,2].set_title('E bdy anomaly')
ax[2,2].set_xlabel('CS distance (m)')


plt.tight_layout()
# Out:
# Day 6 body forcing vs day 6 low bf

# %%
print('Day 9 body forcing vs day 9 low bf')
sns.set_context('talk')
fig,ax = plt.subplots(3,3,figsize=(18,10), sharey = True)

cf1 = ax[0,0].contourf(grid.Y/1000,grid.RC,u_Wbdy_d9,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf1,ax = ax[0,0])
ax[0,0].set_title('West shelf - low bf case, u at day 9')
ax[0,0].set_xlabel('CS distance (m)')

cf2 = ax[1,0].contourf(grid.Y/1000,grid.RC,u_mid_d9,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf2,ax = ax[1,0])
ax[1,0].set_title('mid - low bf case, u at day 9')
ax[1,0].set_xlabel('CS distance (m)')

cf3 = ax[2,0].contourf(grid.Y/1000,grid.RC,u_Ebdy_d9,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf3,ax = ax[2,0])
ax[2,0].set_title('East shelf -fixed boundary case, u at day 9')
ax[2,0].set_xlabel('CS distance (m)')

cf4 = ax[0,1].contourf(grid.Y/1000,grid.RC,ubf_Wbdy_d9,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf4,ax = ax[0,1])
ax[0,1].set_title('West shelf -body forcing case, u at day 9')
ax[0,1].set_xlabel('CS distance (m)')

cf5 = ax[1,1].contourf(grid.Y/1000,grid.RC,ubf_mid_d9,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf5,ax = ax[1,1])
ax[1,1].set_title('mid -body forcing case, u at day 9')
ax[1,1].set_xlabel('CS distance (m)')

cf6 = ax[2,1].contourf(grid.Y/1000,grid.RC,ubf_Ebdy_d9,20, cmap = 'RdYlBu_r', vmax = 0.4, vmin = -0.4)
plt.colorbar(cf6,ax = ax[2,1])
ax[2,1].set_title('East shelf -body forcing case, u at day 9')
ax[2,1].set_xlabel('CS distance (m)')


cf7 = ax[0,2].contourf(grid.Y/1000,grid.RC,u_Wbdy_d9.data-ubf_Wbdy_d9.data,20, cmap = 'RdYlBu_r', vmax = 0.2, vmin = -0.2)
plt.colorbar(cf7,ax = ax[0,2])
ax[0,2].set_title('West shelf anomaly')
ax[0,2].set_xlabel('CS distance (m)')

cf8 = ax[1,2].contourf(grid.Y/1000,grid.RC,u_mid_d9.data-ubf_mid_d9.data,20, cmap = 'RdYlBu_r', vmax = 0.2, vmin = -0.2)
plt.colorbar(cf8,ax = ax[1,2])
ax[1,2].set_title('mid anomaly')
ax[1,2].set_xlabel('CS distance (m)')

cf9 = ax[2,2].contourf(grid.Y/1000,grid.RC,u_Ebdy_d9.data-ubf_Ebdy_d9.data,20, cmap = 'RdYlBu_r', vmax = 0.2, vmin = -0.2)
plt.colorbar(cf9,ax = ax[2,2])
ax[2,2].set_title('East shelf anomaly')
ax[2,2].set_xlabel('CS distance (m)')


plt.tight_layout()
# Out:
# Day 9 body forcing vs day 9 low bf

# %% [markdown]
# ## Alongshelf velocity for different forcing cases

# %%
# Find land mask
hFacmasked = np.ma.masked_values(grid.HFacW.data, 0)
MaskC = np.ma.getmask(hFacmasked)

# %%
sns.set_context('notebook')
sns.set_style('dark')
fig,ax = plt.subplots(1,3,figsize=(14,5), sharey = True)

cf1 = ax[0].contourf(grid.Y[215:300]/1000,grid.RC[0:35],
                     np.ma.array(state_bf.U.isel(Xp1=120,T=slice(6,19),Z=slice(0,35),Y=slice(215,300)).mean(axis=0).data,
                                 mask=MaskC[0:35,215:300,120]),
                     20, 
                     cmap = 'RdYlBu_r', 
                     vmax = 0.4, 
                     vmin = -0.4,
                    )
plt.colorbar(cf1,ax = ax[0])
cnt = ax[0].plot(grid.Y[215:300]/1000,-grid.Depth[215:300,180],'k--')
ax[0].set_axis_bgcolor((205/255.0, 201/255.0, 201/255.0))
ax[0].set_title('Upstream canyon, mean U advective phase, Base case')
ax[0].set_xlabel('CS distance (m)')

cf2 = ax[1].contourf(grid.Y[215:300]/1000,grid.RC[0:35],
                     np.ma.array(state_01.U.isel(Xp1=120,T=slice(6,19),Z=slice(0,35),Y=slice(215,300)).mean(axis=0).data,
                                 mask=MaskC[0:35,215:300,120]),
                     20, 
                     cmap = 'RdYlBu_r',
                     vmax = 0.4, 
                     vmin = -0.4,
                    )
plt.colorbar(cf2,ax = ax[1])
cnt = ax[1].plot(grid.Y[215:300]/1000,-grid.Depth[215:300,180],'k--')
ax[1].set_axis_bgcolor((205/255.0, 201/255.0, 201/255.0))
ax[1].set_title('Low body forcing')
ax[1].set_xlabel('CS distance (m)')

cf3 = ax[2].contourf(grid.Y[215:300]/1000,grid.RC[0:35],
                      np.ma.array(state_fix.U.isel(Xp1=120, T=slice(6,19),Z=slice(0,35),Y=slice(215,300)).mean(axis=0).data,
                                 mask=MaskC[0:35,215:300,120]),
                     20,
                     cmap = 'RdYlBu_r',
                     vmax = 0.4,
                     vmin = -0.4,
                    )
plt.colorbar(cf3,ax = ax[2])
cnt = ax[2].plot(grid.Y[215:300]/1000,-grid.Depth[215:300,180],'k--')
ax[2].set_axis_bgcolor((205/255.0, 201/255.0, 201/255.0))
ax[2].set_title('Fixed boundaries')
ax[2].set_xlabel('CS distance (m)')

ax[0].plot(grid.Y[230:251]/1000,(grid.RC[20].data)*np.ones(np.shape(grid.Y[230:251])),color='0.5')
ax[0].plot(grid.Y[230:251]/1000,(grid.RC[16].data)*np.ones(np.shape(grid.Y[230:251])),color='0.5')
ax[0].plot(((grid.Y[230]/1000).data)*np.ones(np.shape(grid.RC[16:21])),grid.RC[16:21],color='0.5')
ax[0].plot(((grid.Y[250]/1000).data)*np.ones(np.shape(grid.RC[16:21])),grid.RC[16:21],color='0.5')

ax[1].plot(grid.Y[230:251]/1000,(grid.RC[20].data)*np.ones(np.shape(grid.Y[230:251])),color='0.5')
ax[1].plot(grid.Y[230:251]/1000,(grid.RC[16].data)*np.ones(np.shape(grid.Y[230:251])),color='0.5')
ax[1].plot(((grid.Y[230]/1000).data)*np.ones(np.shape(grid.RC[16:21])),grid.RC[16:21],color='0.5')
ax[1].plot(((grid.Y[250]/1000).data)*np.ones(np.shape(grid.RC[16:21])),grid.RC[16:21],color='0.5')

ax[2].plot(grid.Y[230:251]/1000,(grid.RC[20].data)*np.ones(np.shape(grid.Y[230:251])),color='0.5')
ax[2].plot(grid.Y[230:251]/1000,(grid.RC[16].data)*np.ones(np.shape(grid.Y[230:251])),color='0.5')
ax[2].plot(((grid.Y[230]/1000).data)*np.ones(np.shape(grid.RC[16:21])),grid.RC[16:21],color='0.5')
ax[2].plot(((grid.Y[250]/1000).data)*np.ones(np.shape(grid.RC[16:21])),grid.RC[16:21],color='0.5')

plt.ylim(-170,-2.5)
plt.tight_layout()

# %% [markdown]
# This plots show a cross-shelf section upstream of the canyon (xi=120) of the alongshore velocity, U (positive out of the page), averaged over the advective phase (days 3-9) for the base case, low body forcing case and fixed boundaries case. The dotted line is the shelf depth along the canyon axis (xi=180).
#
# The gray rectangle is a somewhat arbitrary selection of a cross section over which to average U, to get useful scale. The only restriction is that I care about the velocity approximately between the shelf location of head and mouth since the pressure gradient we need is between this points.

# %%
sns.set_context('notebook')
sns.set_style('dark')
fig,ax = plt.subplots(1,3,figsize=(14,5), sharey = True)

cf1 = ax[0].contourf(grid.Y[215:300]/1000,grid.RC[0:35],
                     np.ma.array(state_bf.U.isel(Xp1=180,T=slice(6,19),Z=slice(0,35),Y=slice(215,300)).mean(axis=0).data,
                                 mask=MaskC[0:35,215:300,180]),
                     20, 
                     cmap = 'RdYlBu_r', 
                     vmax = 0.4, 
                     vmin = -0.4,
                    )
plt.colorbar(cf1,ax = ax[0])
cnt = ax[0].plot(grid.Y[215:300]/1000,-grid.Depth[215:300,120],'k--')
ax[0].set_axis_bgcolor((205/255.0, 201/255.0, 201/255.0))
ax[0].set_title('Canyon axis, mean U advective phase, Base case')
ax[0].set_xlabel('CS distance (m)')

cf2 = ax[1].contourf(grid.Y[215:300]/1000,grid.RC[0:35],
                     np.ma.array(state_01.U.isel(Xp1=180,T=slice(6,19),Z=slice(0,35),Y=slice(215,300)).mean(axis=0).data,
                                 mask=MaskC[0:35,215:300,180]),
                     20, 
                     cmap = 'RdYlBu_r',
                     vmax = 0.4, 
                     vmin = -0.4,
                    )
plt.colorbar(cf2,ax = ax[1])
cnt = ax[1].plot(grid.Y[215:300]/1000,-grid.Depth[215:300,120],'k--')
ax[1].set_axis_bgcolor((205/255.0, 201/255.0, 201/255.0))
ax[1].set_title('Low body forcing')
ax[1].set_xlabel('CS distance (m)')

cf3 = ax[2].contourf(grid.Y[215:300]/1000,grid.RC[0:35],
                      np.ma.array(state_fix.U.isel(Xp1=180,T=slice(6,19),Z=slice(0,35),Y=slice(215,300)).mean(axis=0).data,
                                 mask=MaskC[0:35,215:300,180]),
                     20,
                     cmap = 'RdYlBu_r',
                     vmax = 0.4,
                     vmin = -0.4,
                    )
plt.colorbar(cf3,ax = ax[2])
cnt = ax[2].plot(grid.Y[215:300]/1000,-grid.Depth[215:300,120],'k--')
ax[2].set_axis_bgcolor((205/255.0, 201/255.0, 201/255.0))
ax[2].set_title('Fixed boundaries')
ax[2].set_xlabel('CS distance (m)')

ax[0].plot(grid.Y[230:251]/1000,(grid.RC[20].data)*np.ones(np.shape(grid.Y[230:251])),color='0.5')
ax[0].plot(grid.Y[230:251]/1000,(grid.RC[16].data)*np.ones(np.shape(grid.Y[230:251])),color='0.5')
ax[0].plot(((grid.Y[230]/1000).data)*np.ones(np.shape(grid.RC[16:21])),grid.RC[16:21],color='0.5')
ax[0].plot(((grid.Y[250]/1000).data)*np.ones(np.shape(grid.RC[16:21])),grid.RC[16:21],color='0.5')

ax[1].plot(grid.Y[230:251]/1000,(grid.RC[20].data)*np.ones(np.shape(grid.Y[230:251])),color='0.5')
ax[1].plot(grid.Y[230:251]/1000,(grid.RC[16].data)*np.ones(np.shape(grid.Y[230:251])),color='0.5')
ax[1].plot(((grid.Y[230]/1000).data)*np.ones(np.shape(grid.RC[16:21])),grid.RC[16:21],color='0.5')
ax[1].plot(((grid.Y[250]/1000).data)*np.ones(np.shape(grid.RC[16:21])),grid.RC[16:21],color='0.5')

ax[2].plot(grid.Y[230:251]/1000,(grid.RC[20].data)*np.ones(np.shape(grid.Y[230:251])),color='0.5')
ax[2].plot(grid.Y[230:251]/1000,(grid.RC[16].data)*np.ones(np.shape(grid.Y[230:251])),color='0.5')
ax[2].plot(((grid.Y[230]/1000).data)*np.ones(np.shape(grid.RC[16:21])),grid.RC[16:21],color='0.5')
ax[2].plot(((grid.Y[250]/1000).data)*np.ones(np.shape(grid.RC[16:21])),grid.RC[16:21],color='0.5')

plt.ylim(-170,-2.5)
plt.tight_layout()

# %% [markdown]
# This plots show a cross-shelf section along the canyon axis (xi=180) of the alongshore velocity, U (positive out of the page), averaged over the advective phase (days 3-9) for the base case, low body forcing case and fixed boundaries case. The dotted line is the shelf depth away from the canyon.

# %%
# State and ptracer files for run with lower bf
state_filelower = '/ocean/kramosmu/MITgcm/TracerExperiments/LOWER_BF/run01/stateGlob.nc'
ptracers_filelower = '/ocean/kramosmu/MITgcm/TracerExperiments/LOWER_BF/run01/ptracersGlob.nc'

state_lower01 = xr.open_dataset(state_filelower)
ptracers_lower01 = xr.open_dataset(ptracers_filelower)

# State and ptracer files for run with low bf
state_filelow = '/ocean/kramosmu/MITgcm/TracerExperiments/LOW_BF/run01/stateGlob.nc'
ptracers_filelow = '/ocean/kramosmu/MITgcm/TracerExperiments/LOW_BF/run01/ptracersGlob.nc'

state_low01 = xr.open_dataset(state_filelow)
ptracers_low01 = xr.open_dataset(ptracers_filelow)

# State and ptracer files for run with lowest bf
state_filelowest = '/ocean/kramosmu/MITgcm/TracerExperiments/LOWEST_BF/run01/stateGlob.nc'
ptracers_filelowest = '/ocean/kramosmu/MITgcm/TracerExperiments/LOWEST_BF/run01/ptracersGlob.nc'

state_lowest01 = xr.open_dataset(state_filelowest)
ptracers_lowest01 = xr.open_dataset(ptracers_filelowest)

# State and ptracer files for run with lower sr
state_filelowersr = '/ocean/kramosmu/MITgcm/TracerExperiments/CNTDIFF_LOWER_SR/run01/stateGlob.nc'
ptracers_filelowersr = '/ocean/kramosmu/MITgcm/TracerExperiments/CNTDIFF_LOWER_SR/run01/ptracersGlob.nc'

state_lowersr01 = xr.open_dataset(state_filelowersr)
ptracers_lowersr01 = xr.open_dataset(ptracers_filelowersr)

# State and ptracer files for run with low sr
state_filelowsr = '/ocean/kramosmu/MITgcm/TracerExperiments/CNTDIFF_LOW_SR/run01/stateGlob.nc'
ptracers_filelowsr = '/ocean/kramosmu/MITgcm/TracerExperiments/CNTDIFF_LOW_SR/run01/ptracersGlob.nc'

state_lowsr01 = xr.open_dataset(state_filelowsr)
ptracers_lowsr01 = xr.open_dataset(ptracers_filelowsr)

# %%
U_in_lowbf = state_low01.U.isel(Xp1=120, Z=slice(16,21),Y=slice(230,251))
U_in_lowerbf = state_lower01.U.isel(Xp1=120, Z=slice(16,21),Y=slice(230,251))
U_in_lowestbf = state_lowest01.U.isel(Xp1=120, Z=slice(16,21),Y=slice(230,251))
U_in_base = state_bf.U.isel(Xp1=120, Z=slice(16,21),Y=slice(230,251))
U_in_fix = state_fix.U.isel(Xp1=120, Z=slice(16,21),Y=slice(230,251))
U_in_spndn = state_spndn.U.isel(Xp1=120, Z=slice(16,21),Y=slice(230,251))
U_in_lowsr = state_lowsr01.U.isel(Xp1=120, Z=slice(16,21),Y=slice(230,251))
U_in_lowersr = state_lowersr01.U.isel(Xp1=120, Z=slice(16,21),Y=slice(230,251))

Ubflow = state_low01.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).mean()
Ubflower = state_lower01.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).mean()
Ubflowest = state_lowest01.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).mean()
Ubase = state_bf.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).mean()
Ufix = state_fix.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).mean()
Uspn = state_spndn.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).mean()
Ubflowsr = state_lowsr01.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).mean()
Ubflowersr = state_lowersr01.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).mean()


STDbflow = state_low01.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).std()
STDbflower = state_lower01.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).std()
STDbflowest = state_lowest01.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).std()
STDbase = state_bf.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).std()
STDfix = state_fix.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).std()
STDspn = state_spndn.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).std()
STDbflowsr = state_lowsr01.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).std()
STDbflowersr = state_lowersr01.U.isel(T=slice(6,18),Xp1=120, Z=slice(16,21),Y=slice(230,251)).std()

# %%
sns.set_context('notebook')
sns.set_style('whitegrid')
fig,ax = plt.subplots(1,1,figsize=(9,5), sharey = True)

ax.plot(np.linspace(0,9,19),np.mean(np.mean(U_in_base,axis=1),axis=1),color='g',
        label='base case, $U_{in}$=%0.3f $\pm$ %0.3f m/s' %(Ubase,STDbase))
ax.plot(np.linspace(0,9,19),np.mean(np.mean(U_in_lowerbf,axis=1),axis=1),color='b',
        label='lower bf, $U_{in}$=%0.3f $\pm$ %0.3f m/s' %(Ubflower,STDbflower) )
ax.plot(np.linspace(0,9,19),np.mean(np.mean(U_in_lowbf,axis=1),axis=1),color='r',
        label='low bf, $U_{in}$=%0.3f $\pm$ %0.3f m/s' %(Ubflow,STDbflow) )
ax.plot(np.linspace(0,9,19),np.mean(np.mean(U_in_lowestbf,axis=1),axis=1),color='y',
        label='lowest bf, $U_{in}$=%0.3f $\pm$ %0.3f m/s' %(Ubflowest,STDbflowest) )
ax.plot(np.linspace(0,9,19),np.mean(np.mean(U_in_fix,axis=1),axis=1),color='orange',
        label='fixed u,v, $U_{in}$=%0.3f $\pm$ %0.3f m/s' %(Ufix,STDfix))
ax.plot(np.linspace(0,9,19),np.mean(np.mean(U_in_spndn,axis=1),axis=1),color='purple',
        label='Spin down, $U_{in}$=%0.3f $\pm$ %0.3f m/s' %(Uspn,STDspn))
ax.plot(np.linspace(0,9,19),np.mean(np.mean(U_in_lowersr,axis=1),axis=1),color='teal',
        label='lower sr, $U_{in}$=%0.3f $\pm$ %0.3f m/s' %(Ubflowersr,STDbflowersr) )
ax.plot(np.linspace(0,9,19),np.mean(np.mean(U_in_lowsr,axis=1),axis=1),color='orchid',
        label='low sr, $U_{in}$=%0.3f $\pm$ %0.3f m/s' %(Ubflowsr,STDbflowsr) )

ax.set_ylabel('Incoming U (m/s)')
ax.set_xlabel('days')
ax.legend(loc=0)

# %%
mean()
