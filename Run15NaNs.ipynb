# %%
from math import *

import matplotlib.pyplot as plt

import matplotlib.colors as mcolors
# %matplotlib inline
from MITgcmutils import rdmds

from netCDF4 import Dataset

import numpy as np

import os 

import pandas as pd

import pylab as pl

import scipy.io

import scipy as spy

import seaborn as sns

import sys

# import my modules
lib_path = os.path.abspath('../../Building_canyon/BuildCanyon/PythonModulesMITgcm') # Add absolute path to my python scripts
#lib_path = os.path.abspath('../BuildCanyon/PythonModulesMITgcm') # Add absolute path to my python scripts
sys.path.append(lib_path)

import ReadOutTools_MITgcm as rout 
import MetricsPythonTools as mpt

# %%
CGrid = '/ocean/kramosmu/MITgcm/TracerExperiments/CNTDIFF/run15/gridGlob.nc' # Smallest volume grid, closed bdy, no canyon.
CGridOut = Dataset(CGrid)
CState = '/ocean/kramosmu/MITgcm/TracerExperiments/CNTDIFF/run15/stateGlob.nc' # Smallest volume grid, closed bdy, no canyon.

# General input

nx = 360
ny = 360
nz = 90
nt = 19 # t dimension size 
numTr = 3 # number of tracers in run

rc = CGridOut.variables['RC']

xc = rout.getField(CGrid, 'XC') # x coords tracer cells
yc = rout.getField(CGrid, 'YC') # y coords tracer cells

drF = CGridOut.variables['drF'] # vertical distance between faces
drC = CGridOut.variables['drC'] # vertical distance between centers

hFacC = rout.getField(CGrid, 'HFacC')
MaskC = rout.getMask(CGrid, 'HFacC')
rA = rout.getField(CGrid, 'rA')

hFacS = rout.getField(CGrid, 'HFacS')
MaskS = rout.getMask(CGrid, 'HFacS')

hFacW = rout.getField(CGrid, 'HFacW')
MaskW = rout.getMask(CGrid, 'HFacW')

# %%
Mask = MaskC
#Temp = rout.getField(CState,'Temp')
S = rout.getField(CState,'S')
#W = rout.getField(CState,'W')


#Mask = MaskW
#U = rout.getField(CState,'U')
#Mask = MaskS
#V = rout.getField(CState,'V')

maskExp = mpt.maskExpand(Mask,S)

#UMask = np.ma.array(U,mask = maskExp)
#VMask = np.ma.array(V,mask = maskExp)
#WMask = np.ma.array(W,mask = maskExp)

#TempMask=np.ma.array(Temp,mask=maskExp)   
SMask=np.ma.array(S,mask=maskExp)

# %%
def plotFld(ax,Fld):
    pc = ax.pcolor(Fld, cmap = 'rainbow')
    cb = plt.colorbar(pc)

# %%
fig1 = plt.figure(figsize=(10,10))
ax1 = plt.subplot(1,1,1)
plotFld(ax1,SMask[1,:,:,1])

# %%
fig1 = plt.figure(figsize=(10,10))
ax1 = plt.subplot(1,1,1)
plotFld(ax1,SMask[0,:,:,180])
